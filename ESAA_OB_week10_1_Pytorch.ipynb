# %% [markdown]
# <a href="https://colab.research.google.com/github/yunju-1118/ESAA/blob/OB/ESAA_OB_week10_1_Pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **머신러닝과 딥러닝**

# %% [markdown]
# **1. 인공지능, 머신러닝과 딥러닝**
# 인공지능은 인간의 지능을 모방하여 사람이 하는 일을 컴퓨터가 할 수 있도록 하는 기술이다. 인공지능을 구현하는 방법으로 머신러닝과 딥러닝이 있다.
#
# 인공지능과 머신러닝, 딥러닝의 관계는 다음과 같다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 머신러닝과 딥러닝 모두 학습 모델을 제공하여 데이터를 분류하는 기술이다. 하지만, 둘의 접근 방식에는 차이가 있다. **머신러닝**의 학습 과정은 각 데이터 특성을 컴퓨터에 인식시키고 학습시켜 문제를 해결한다. 반면 **딥러닝**은 인간이 하던 작업을 생략하고 대량의 데이터를 신경망에 적용해 컴퓨터가 스스로 분석 후 답을 찾는다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **2. 머신러닝이란**
#
# 머신러닝은 인공지능의 한 분야로, 컴퓨터가 학습할 수 있게 하는 알고리즘과 기술을 개발하는 분야이다.

# %% [markdown]
# ### **2.1. 머신러닝 학습 과정**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **2.2. 머신러닝 학습 알고리즘**
# 머신러닝의 학습 알고리즘으로는 지도 학습, 비지도학습, 강화학습이 있다.
#
# **지도학습**은 정답이 무엇인지 컴퓨터에 알려주고 학습시키는 방법이다.
#
# 반면, **비지도학습**은 정답을 알려주지 않고 특징이 비슷한 데이터를 클러스팅하여 예측하는 학습 방법이다.
#
# **강화 학습**은 자신의 행동에 대한 보상을 받으며 학습을 진행한다.
#
# 지도학습, 비지도 학습, 강화 학습에서 자주 사용되는 알고리즘은 다음과 같다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **3. 딥러닝이란**
# 딥러닝은 인간의 신경망 원리를 모방한 심층 신경망 이론을 기반으로 고안된 머신런이 방법의 일종이다. 즉, 딥러닝이 머신러닝과 다른 큰 차이점은 **인간의 뇌를 기초로 하여 설계**했다는 것이다.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **3.1. 딥러닝 학습 과정**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 딥러닝의 학습 과정도 머신러닝과 크게 다르지 않다.
#
# - **데이터 준비**
# - **모델(모형) 정의**: 모델(모형) 정의 단계에서 신경망을 생성한다.
# - **모델(모형) 컴파일**: 컴파일 단계에서 활성화 함수, 손실 함수, 옵티마이저를 선택한다. 이때 데이터 형태에 따라 다양한 옵션이 가능하다.
# - **모델(모형) 훈련**: 훈련 단계에서는 한 번에 처리할 데이터양을 지정한다. 이때 전체 훈련 데이텃세에서 일정한 묶음으로 나누어 처리할 수 있는 배치와 훈련의 횟수인 에포크 선택이 중요하다.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - **모델(모형) 예측**: 검증 데이터셋을 생성한 모델(모형)에 적용하여 실제로 예측을 진행해 보는 단계이다.
#
# 딥러닝 학습 과정에서 중요한 핵심 구성 요소는 **신경망**과 **역전파**이다.
# 심층 신경망에는 데이터셋의 어떤 특성들이 중요한지 가르쳐줄 수 있는 기능이 있으며, 역전파는 가중치 값을 업데이트할 수 있다. 특히, 역전파 계산 과정에서 사용되는 미분이 성능에 영향을 미치는 주요한 요소라고 할 수 있다.

# %% [markdown]
# ### **3.2. 딥러닝 학습 알고리즘**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 딥러닝은 활용 분야에 따라 지도 학습과 비지도 학습, 전이 학습으로 분류된다.
#
# 지도학습으로 분류되는 알고리즘에는 컴퓨터 비전에서 가장 많이 사용되는 **합성곱 신경망** 그리고 시계열 데이터를 분류할 때 사용되는 **순환 신경망**이 있다.
#
# 비지도학습으로는 **워드 임베딩**과 **군집**이 있다.
#
# 전이학습은 사전에 학습이 완료된 모델(**pre-trained model**)을 갖고 우리가 원하는 학습에 미세 조정 기법을 이용해 학습시키는 방법이다.

# %% [markdown]
# # **파이토치 기초**

# %% [markdown]
# ## **1. 파이토치 개요**
# **파이토치(Pytorch)**는 2017년 초에 공개된 딥러닝 프레임워크로 루아 언어로 개발되었던 토치를 페이스북에서 파이썬 버전으로 내놓은 것이다.

# %% [markdown]
# ### **1.1. 파이토치 특징 및 장점**
# 파이토치 특징은 다음과 같다.
#
# **GPU에서 텐서 조작 및 동적 신경망 구축이 가능한 프레임 워크**
#
# 파이토치는 효율적인 계산, 낮은 CPU 활용, 직관적인 인터페이스와 낮은 진입 장벽 등을 장점으로 꼽을 수 있다.

# %% [markdown]
# ### 1.2. **파이토치 아키텍처**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### **파이토치 API**
# - **torch**: GPU를 지원하는 텐서 패키지
# - **torch.autograd**: 자동 미분 패키지
# - **torch.nn**: 신경망 구축 및 훈련 패키지
# - **torch.multiprocessing**: 파이썬 멀티프로세싱 패키지
# - **torch.utils**: DataLoader 및 기타 유틸리티를 제공하는 패키지

# %% [markdown]
# ## **2. 파이토치 기초 문법**

# %% [markdown]
# ### **2.1. 텐서 다루기**

# %% [markdown]
# #### **텐서 생성 및 변환**
# 텐서는 파이토치의 가장 기본이 되는 데이터 구조이다. 넘파이의 ndarray와 비슷하며 GPU에서의 연산도 가능하다.

# %%
import torch
print(torch.tensor([[1,2],[3,4]]))   # 2차원 형태의 텐서 생성
print(torch.tensor([[1,2],[3,4]], device="cuda:0"))    # GPU에 텐서 생성
print(torch.tensor([[1,2],[3,4]], dtype=torch.float64))  # dtype을 이용하여 텐서 생성
# Out:
# tensor([[1, 2],
#         [3, 4]])
# tensor([[1, 2],
#         [3, 4]], device='cuda:0')
# tensor([[1., 2.],
#         [3., 4.]], dtype=torch.float64)

# %%
temp = torch.tensor([[1,2],[3,4]])
print(temp.numpy())  # 텐서를 ndarray로 변환

temp = torch.tensor([[1,2],[3,4]],device="cuda:0")
print(temp.to("cpu").numpy())   # GPU 상의 텐서를 CPU의 텐서로 변환한 후 ndarray로 변환
# Out:
# [[1 2]
#  [3 4]]
# [[1 2]
#  [3 4]]

# %% [markdown]
# #### **텐서의 인덱스 조작**

# %%
temp = torch.FloatTensor([1,2,3,4,5,6,7])
print(temp[0],temp[1],temp[-1])
print('-------------------------------')
print(temp[2:5],temp[4:-1])
# Out:
# tensor(1.) tensor(2.) tensor(7.)
# -------------------------------
# tensor([3., 4., 5.]) tensor([5., 6.])

# %% [markdown]
# #### **텐서 연산 및 차원 조작**

# %%
v = torch.tensor([1,2,3])  # 길이가 3인 벡터 생성
w = torch.tensor([3,4,6])
print(w-v)   # 길이가 같은 벡터 간 뺄셈 연산
# Out:
# tensor([2, 2, 3])

# %%
temp = torch.tensor([
    [1,2], [3,4]   # 2*2 행렬 생성
])

print(temp.shape)
print('----------------------------')
print(temp.view(4,-1))
print('----------------------------')
print(temp.view(-1))
print('----------------------------')
print(temp.view(1,-1))
print('----------------------------')
print(temp.view(-1,1))
# Out:
# torch.Size([2, 2])
# ----------------------------
# tensor([[1],
#         [2],
#         [3],
#         [4]])
# ----------------------------
# tensor([1, 2, 3, 4])
# ----------------------------
# tensor([[1, 2, 3, 4]])
# ----------------------------
# tensor([[1],
#         [2],
#         [3],
#         [4]])

# %% [markdown]
# ### **2.2. 데이터 준비**

# %% [markdown]
# #### **단순하게 파일을 불러와서 사용**
#
# ```
# import pandas as pd
# import torch
# data = pd.read_csv('../class2.csv')
#
# x = torch.from_numpy(data['x'].values).unsqueeze(dim=1).float()
# y = torch.from_numpy(data['y'].values).unsqueeze(dim=1).float()
# ```

# %% [markdown]
# #### **커스텀 데이터셋을 만들어서 사용**

# %% [markdown]
# 데이터를 한 번의 다 부르지 않고, 조금씩 나누어 불러서 사용하는 방식이 커스텀 데이터셋이다.
#
# ```
# import pandas as pd
# import torch
# from torch.utils.data import Dataset
# from torch.utils.data import DataLoader
#
# class CustomDataset(Dataset):
#     def __init__(self, csv_file):
#         self.label = pd.read_csv(csv_file)
#
#     def __len__(self):
#         return len(self.label)
#
#     def __getitem__(self, idx):
#         sample = torch.tensor(self.label.iloc[idx,0:3]).int()
#         label = torch.tensor(self.label.iloc[idx,3]).int()
#         return sample, label
#
# tensor_dataset = CustomDataset('../covtype.csv')
# dataset = DataLoader(tensor_dataset, batch_size=4, shuffle=True)
# ```

# %% [markdown]
# #### **파이토치에서 제공하는 데이터셋 사용**

# %% [markdown]
# 토치비전(torchvision)은 파이토치에서 제공하는 데이터셋들이 모여 있는 패키지이다. 파이토치에서 제공하는 데이터셋을 내려받으려면 먼저 requests 라이브러리를 설치해야 한다.

# %%
# !pip install requests

# %% [markdown]
# ```
# import torchvision.transforms as transforms
#
# mnist_transform = transforms.Compose([
#     transforms.ToTensor(),
#     transforms.Normalize((0.5,),(1.0,))
# ])
#
# from torchvision.datasets import MNIST
# import requests
# download_root = '../chap02/data/MNIST_DATASET'
#
# train_dataset = MNIST(download_root, transform=mnist_transform, train=True,
#                       download=True)
# valid_dataset = MNIST(download_root, transform=mnist_transform, train=False,
#                       download=True)
# test_dataset = MNIST(download_root, transform=mnist_transform, train=False,
#                       download=True)
# ```

# %% [markdown]
# ### **2.3. 모델 정의**

# %% [markdown]
# 파이토치에서 모델을 정의하기 위해서는 모듈을 상속한 클래스를 사용한다.
#
# - **계층(layer)**: 모듈 또는 모듈을 구성하는 한 개의 계층으로 합성곱층, 선형계층 등이 있다.
#
# - **모듈(module)**: 한 개 이상의 계층이 모여서 구성된 것으로, 모듈이 모여 새로운 모듈을 만들 수도 있다.
# - **모델(model)**: 최종적으로 원하는 네트워크로 한 개의 모듈이 모델이 될 수도 있다.

# %% [markdown]
# #### **단순 신경망을 정의하는 방법**
# nn.Module을 상속받지 않는 매우 단순한 모델을 만들 때 사용한다. 구현이 쉽고 단순하다는 장점이 있따.
#
# ```
# model = nn.Linear(in_features=1, out_features=1, bias=True)
# ```

# %% [markdown]
# #### **nn.Module()을 상속하여 정의하는 방법**
# 파이토치에서 nn.Module을 상속받는 모델은 기본적으로 __init__()과 forward( ) 함수를 포함한다.
#
# ```
# class MLP(Module):
#     def __init__(self, inputs):
#         super(MLP, self).__init__()
#         self.layer = Linear(inputs, 1)
#         self.activation = Sigmoid( )
#
#     def forward(self, X):
#         X = self.layer(X)
#         y = self.acitvation(X)
#         return X
# ```

# %% [markdown]
# #### **Sequential 신경망을 정의하는 방법**
# nn.Sequetial을 사용하면 __init__( )에서 사용할 네트워크 모델들을 정의해 줄 뿐만 아니라 forward( ) 함수에서는 모델에서 실행되어야 할 계산을 가독성이 뛰어나게 코드로 작성할 수 있다.

# %%
import torch.nn as nn
class MLP(nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=64, kernel_size=5),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2)
        )

        self.layer2 = nn.Sequential(
            nn.Conv2d(in_channels=64, out_channels=30, kernel_size=5),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2)
        )

        self.layer3 = nn.Sequential(
            nn.Linear(in_features=30*5*5, out_features=10, bias=True),
            nn.ReLU(inplace=True)
        )

        def forward(self,x):
            x = self.layer1(x)
            x = self.layer2(x)
            x = x.view(x.shape[0],-1)
            x = self.layer3(x)
            return x

model = MLP()

print("Printing children \n-------------------------------")
print(list(model.children()))
print("\n\nPrinting Modules \n-------------------------------")
print(list(model.modules()))
# Out:
# Printing children
# -------------------------------
# [Sequential(
#   (0): Conv2d(3, 64, kernel_size=(5, 5), stride=(1, 1))
#   (1): ReLU(inplace=True)
#   (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# ), Sequential(
#   (0): Conv2d(64, 30, kernel_size=(5, 5), stride=(1, 1))
#   (1): ReLU(inplace=True)
#   (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# ), Sequential(
#   (0): Linear(in_features=750, out_features=10, bias=True)
#   (1): ReLU(inplace=True)
# )]
#
#
# Printing Modules
# -------------------------------
# [MLP(
#   (layer1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer2): Sequential(
#     (0): Conv2d(64, 30, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU(inplace=True)
# ...

# %% [markdown]
# #### **함수로 신경망을 정의하는 방법**
# Sequential을 이용하는 것과 동일하지만, 함수로 선언할 경우 변수에 저장해놓은 계층들을 재사용할 수 있다는 장점이 있다. 하지만, 모델이 복잡해지는 단점도 존재한다.

# %%
def MLP(in_features=1, hidden_features=20, out_features=1):
    hidden = nn.Linear(in_features=in_features, out_features=hidden_features,
                       bias=True)
    activation = nn.ReLU()
    output = nn.Linear(in_features=hidden_features, out_features=out_features,
                       bias=True)
    net = nn.Sequential(hidden, activation, output)
    return net

# %% [markdown]
# ### **2.4. 모델의 파라미터 정의**
# - **손실 함수(loss function)**: 학습하는 동안 출력과 실제 값 사이의 오차를 측정한다.
# - **옵티마이저(Optimizer)**: 데이터와 손실함수를 바탕으로 모델의 업데이트 방법을 결정한다.
# - **학습률 스케줄러(learning rate scheduler)**: 미리 지정한 횟수의 에포크를 지날 때마다 학습률을 감소시켜 준다.
#
# ```
# from torch.optim import optimizer
# criterion = torch.nn.MSELoss()
# optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
# scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer=optimizer,
#                                     lr_labmda=lambda epoch:0.95 ** epoch)
#
# for epoch in range(1, 100+1):
#     for x, y in dataloader:
#         optimizer.zero_grad()
# loss_fn(model(x),y).backward()
# optimizer.step()
# scheduler.step()
# ```

# %% [markdown]
# ### **2.5. 모델 훈련**
# 앞서 만들어 둔 데이터로 모델을 학습시킨다. 이때 학습을 시킨다는 것은 $y=wx+b$라는 함수에서 $w$와 $b$의 적절한 값을 찾는다는 의미이다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
# for epoch in range(100):
#     yhat = model(x_train)
#     loss = criterion(yhat, y_train)
#     optimizer.zero_grad()
#     loss.backward()
#     optimizer.step()
# ```

# %% [markdown]
# ### **2.6. 모델 평가**

# %%
# !pip install torchmetrics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 24.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# ```
# # 함수를 이용하여 모델 평가
# import torch
# import torchmetrics
#
# preds = torch.randn(10,5).softmax(dim=-1)
# target = torch.randint(5, (10,))
#
# acc = torchmetrics.functional.accuracy(preds,target)
# ```

# %% [markdown]
# ```
# # 모듈을 이용하여 모델 평가
# import torch
# import torchmetrics
# metric = torchmetrics.Accuracy()
#
# n_batches = 10
# for i in range(n_batches):
#   preds = torch.randn(10,5).softmax(dim=-1)
#   target = torch.randint(5,(10,))
#
#   acc = metric(preds, target)
#   print(f"Accuracy on batch {i}: {acc}")
#
# acc = metric.compute()
# print(f"Accuracy on all data: {acc}")
# ```

# %% [markdown]
# ### **2.7. 훈련 과정 모니터링**
# 텐서보드를 이용하면 학습에 사용되는 각종 파라미터 값이 어떻게 변화하는지 손쉽게 시각화하여 살펴볼 수 있으며 성능을 추적하거나 평가하는 용도로 사용할 수 있다. 파이토치에서 텐서보드를 사용하는 방법은 다음과 같다.
#
# 1. 텐서보드를 설정한다.
# 2. 텐서보드에 기록한다.
# 3. 텐서보드를 사용하여 모델 구조를 살펴본다.

# %%
# !pip install tensorboard

# %% [markdown]
# ```
# import torch
# from torch.utils.tensorboard import SummaryWriter
# writer = SummaryWriter('../chap02/tensorboard')
#
# for epoch in range(num_epochs):
#   model.train()
#   batch_loss = 0.0
#
#   for i, (x, y) in enumerate(dataloader):
#     x, y = x.to(device).float(), y.to(device).float()
#     outputs = model(x)
#     loss = criterion(outputs, y)
#     writer.add_scalar("Loss", loss, epoch)
#     optimizer.zero_grad()
#     loss.backward()
#     optimizer.step()
#
# writer.close()
# ```

# %% [markdown]
# 다음 명령을 입력하면 텐서보드를 실행할 수 있다.
#
# > **tensorboard --logdir=../chap02/tensorboard --port=6006**
