# %% [markdown]
# <a href="https://colab.research.google.com/github/yunju-1118/ESAA/blob/main/YB_5_9_%EC%84%B8%EC%85%98_%EC%97%B0%EC%8A%B5%EB%AC%B8%EC%A0%9C_%ED%9A%8C%EA%B7%801.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. 단순 선형 회귀 분석**
# - 전복의 나이를 예측하는 선형회귀모델을 생성하세요.
# - 전복의 ‘성별’, ‘키’, ‘지름’, ‘높이’, ‘전체무게’, ‘몸통무게’, ‘내장무게’, ‘껍질무게’를 이용해 ‘껍질의 고리 수’를 예측한 뒤, **예측된 ‘껍질의 고리 수’에 1.5를 더하면 전복의 나이**가 됩니다.

# %%
# 기본 모듈 불러오기
import numpy as np
import pandas as pd

# %% [markdown]
# **1) 데이터 load 및 변형**

# %%
# 데이터 로드
data = pd.read_csv("abalone.csv")
data.head()
print(data.shape)

# 성별 M은 Male, F는 Female, I는 Infant 이므로 따로 열 만들기
for label in "MFI":
    data[label] = data["Sex"] == label
data.drop('Sex', axis=1, inplace=True)
# Out:
# (4177, 9)

# %% [markdown]
# **2) X, y 선택**
# : y는 Rings열, X는 Rings열을 제외한 나머지를 선택하되 전부 실수가 되도록 한다.

# %%
# X,y 데이터 선택
y = data['Rings']

X = data.drop('Rings', axis=1)

# %% [markdown]
#  **3) train/test set 분리**

# %%
# 필요한 모듈 불러오기
from sklearn.model_selection import train_test_split

# %%
# train과 test set 분리 (train:test = 7:3 비율로)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %% [markdown]
# **4) 선형회귀모델 생성, 모델 예측치 구하기**

# %%
#필요한 모듈 불러오기
from sklearn.linear_model import LinearRegression

# %%
#선형회귀모델 생성 및 훈련
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# 모델 예측치 구하기
y_pred = lr.predict(X_test)
# 모델 예측치를 활용해 최종적으로 전복의 나이를 예측
y_pred = y_pred + 1.5

# %% [markdown]
# **5) 모델 평가: MSE, RMSE, R2 score, corr 구하기**

# %%
#필요한 모듈 불러오기
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# - MSE, RMSE

# %%
#mse, rmse
print('mse:',mean_squared_error(y_test, y_pred))
print('rmse:',np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# mse: 7.0619968790976975
# rmse: 2.6574417922313365

# %% [markdown]
# - R2 score

# %%
#R2 score 측정

print('r2_score:',r2_score(y_test, y_pred))
# Out:
# r2_score: 0.3301726127446132

# %% [markdown]
# - 회귀 절편값

# %%
#회귀 절편 값
print('절편 값:', lr.intercept_)
# Out:
# 절편 값: 3.744965361460352

# %% [markdown]
# - 회귀 계수 값

# %%
#회귀 계수 값
print('회귀 계수값:', np.round(lr.coef_,1))
# Out:
# 회귀 계수값: [ -0.1  11.2   7.1   9.  -20.  -10.7   9.6   0.3   0.2  -0.6]

# %% [markdown]
# - 상관계수
#
# Hint: corr 함수 이용.

# %%
# 상관계수 구하기
X_train.corr()
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.986287  0.798809      0.926342        0.899607
# Diameter        0.986287  1.000000  0.805025      0.926179        0.894507
# Height          0.798809  0.805025  1.000000      0.791527        0.751385
# Whole weight    0.926342  0.926179  0.791527      1.000000        0.968414
# Shucked weight  0.899607  0.894507  0.751385      0.968414        1.000000
# Viscera weight  0.904583  0.900813  0.770926      0.966928        0.932593
# Shell weight    0.895683  0.903621  0.786632      0.953074        0.877433
# M               0.236010  0.237901  0.211000      0.252432        0.250047
# F               0.308613  0.319438  0.287827      0.299358        0.267097
# I              -0.554292 -0.567090 -0.507479     -0.562113       -0.527353
#
#                 Viscera weight  Shell weight         M         F         I
# Length                0.904583      0.895683  0.236010  0.308613 -0.554292
# Diameter              0.900813      0.903621  0.237901  0.319438 -0.567090
# Height                0.770926      0.786632  0.211000  0.287827 -0.507479
# Whole weight          0.966928      0.953074  0.252432  0.299358 -0.562113
# Shucked weight        0.932593      0.877433  0.250047  0.267097 -0.527353
# Viscera weight        1.000000      0.905623  0.237995  0.313478 -0.561225
# Shell weight          0.905623      1.000000  0.235981  0.303004 -0.548650
# M                     0.237995      0.235981  1.000000 -0.520359 -0.519534
# F                     0.313478      0.303004 -0.520359  1.000000 -0.459311
# I                    -0.561225     -0.548650 -0.519534 -0.459311  1.000000

# %% [markdown]
# # **2. Polynomial features**

# %%
# PolynomialFeatures 라이브러리 호출
from sklearn.preprocessing import PolynomialFeatures

# %%
# 임의 데이터 생성

X = np.arange(6).reshape(3, 2)

df =  pd.DataFrame(X)
df.columns = ['x_1','x_2']
df
# Out:
#    x_1  x_2
# 0    0    1
# 1    2    3
# 2    4    5

# %%
# 차원은 2로 설정
# fit_transform 메소드를 통해 데이터 변환
# PolynomialFeatures로 변환 된 데이터를 데이터 프레임 형태로 변환
poly_ftr = PolynomialFeatures(degree=2).fit_transform(X)
df_poly = pd.DataFrame(poly_ftr)

# %%
# df_poly의 컬럼을 1,x1,x2,x1^2,x1*x2,x2^2 로 변경
df_poly.columns = ['1', 'x1', 'x2', 'x1^2', 'x1*x2', 'x2^2']

print(df_poly)
# Out:
#      1   x1   x2  x1^2  x1*x2  x2^2
# 0  1.0  0.0  1.0   0.0    0.0   1.0
# 1  1.0  2.0  3.0   4.0    6.0   9.0
# 2  1.0  4.0  5.0  16.0   20.0  25.0
